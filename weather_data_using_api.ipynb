# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
import requests
import os
from datetime import datetime

# Use your real API key here or via environment variable
user_api="f2eac17ba431017098b978b9f53c3a3b"
print("DEBUG:", os.getenv("f2eac17ba431017098b978b9f53c3a3b"))
print("Using API key:", user_api)

if not user_api:
    raise ValueError("API key not found. Please set OPENWEATHER_API_KEY environment variable.")

location = input("Enter the city name: ")

complete_api_link = f"https://api.openweathermap.org/data/2.5/weather?q={location}&appid={user_api}&units=metric"

api_link = requests.get(complete_api_link, timeout=10)

if api_link.status_code != 200:
    print(f"Error {api_link.status_code}: {api_link.text}")
else:
    api_data = api_link.json()

    # Extract values
    temp_city = api_data['main']['temp']
    weather_desc = api_data['weather'][0]['description']
    hmdt = api_data['main']['humidity']
    wind_spd = api_data['wind']['speed']
    date_time = datetime.now().strftime("%d %b %Y | %I:%M:%S %p")

    # Print nicely formatted report
    print("-----------------------------------------------------")
    print(f"Weather Stats for - {location.upper()} || {date_time}")
    print("-----------------------------------------------------")
    print(f"Current temperature : {temp_city:.2f} °C")
    print(f"Current weather     : {weather_desc}")
    print(f"Humidity            : {hmdt}%")
    print(f"Wind speed          : {wind_spd} km/h")
# Out:
# DEBUG: None
# Using API key: f2eac17ba431017098b978b9f53c3a3b
# Enter the city name: Kolkata
# -----------------------------------------------------
# Weather Stats for - KOLKATA || 21 May 2026 | 04:24:00 AM
# -----------------------------------------------------
# Current temperature : 31.97 °C
# Current weather     : haze
# Humidity            : 79%
# Wind speed          : 4.63 km/h
